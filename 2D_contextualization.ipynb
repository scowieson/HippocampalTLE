# %%
### 2d contextualization

# %%
import numpy as np
import hippomaps as hm

# %%
MICs_context = np.load('file_MICS_caseCtrl.npy') 
NKG_context = np.load('file_NKG_caseCtrl.npy')
EpiC_context = np.load('file_EpiC_caseCtrl.npy')

# %%
sum = (MICs_context + NKG_context + EpiC_context)
average = sum/3
average
# Out:
# array([[-4.01228288e-03, -4.51189214e-05,  1.50918997e-01],
#        [ 8.06251709e-03, -4.37408912e-05, -1.77419471e-02],
#        [ 9.99179345e-03, -5.08811221e-05,  4.86753530e-03],
#        ...,
#        [-5.67832572e-03, -1.74890250e-04,  2.26006601e-01],
#        [-1.30215699e-02, -1.52279521e-04,  1.90547188e-01],
#        [-1.73569790e-02, -1.44460974e-04,  1.03815701e-01]])

# %%
hm.stats.contextualize2D(average)
# Out:
# (array([['iEEG-BandPower-alpha', 'MRI-7T-FA', 'iEEG-BandPower-beta'],
#         ['iEEG-BandPower-delta', 'iEEG-BandPower-alpha',
#          'histology-Calretinin'],
#         ['MRI-7T-thickness', 'MRI-3T-rsfMRI-avgFCneocort',
#          'MRI-7T-gyrification']], dtype=object),
#  array([[-0.37828127, -0.35768339, -0.35581817],
#         [-0.65647435,  0.63968026, -0.51334701],
#         [ 0.33263004,  0.31358256,  0.29385321]]),
#  array([[0.037, 0.018, 0.047],
#         [0.   , 0.   , 0.   ],
#         [0.   , 0.002, 0.001]]),
#  array([[0.3766362 , 0.41283794, 0.10093219]]),
#  array([0.22167158, 0.53553583, 0.43338775]),
#  <Axes: xlabel="absolute AP correlation (Pearnson's R)", ylabel="absolute subfield correlation (Spearmann's R)">)
